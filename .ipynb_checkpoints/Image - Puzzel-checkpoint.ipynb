# %%
from PIL import Image

# %%
wm = Image.open('Working-with-Images\\word_matrix.png')

# %%
wm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x211E6FB74F0>

# %%
h, w = wm.size

# %%
ms = Image.open('Working-with-Images\\mask.png')

# %%
ms = ms.resize((h, w))

# %%
ms
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x211E6FA73A0>

# %%
ms.putalpha(70)

# %%
ms
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x211E6FA73A0>

# %%
wm.paste(ms, box=(0,0), mask=ms)

# %%
wm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x211E6FB74F0>
